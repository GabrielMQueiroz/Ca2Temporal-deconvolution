# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import neuron as h
import h5py

# %% [markdown]
# # Loading calcium imaging data
#
# Calcium imaging recordings of layer 5 pyramidals neurons of A1
#
# The recording were done with UCLA miniscope V.3 at 20fps with GCAMP6f

# %%
CaData=h5py.File('/media/orion/PersonalBs/Lascon_Ca_Project/Data/analysis_results_pre.hdf5','r')
CaTrace=CaData['estimates']['C'][CaData['estimates']['idx_components'][:]]

# %% [markdown]
# ### Sanity ploting

# %%
plt.plot(CaTrace[10])
plt.title('Calcium Trace for Neuron 10')
plt.xlabel('Time (frames)')
plt.ylabel('Fluorescence Intensity[a.u.]')
plt.show()

# %% [markdown]
# ## Create Neuron

# %% [markdown]
# ### Sanity check for the neuron
